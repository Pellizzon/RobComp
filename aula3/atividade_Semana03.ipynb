# %% [markdown]
# # Entregável 3 de Visão Computacional e Robótica

# %% [markdown]
# Entrega até 12/03 ao fim do atendimento

# %% [markdown]
# Pode ser feito **em duplas**

# %% [markdown]
# Nesta semana vamos trabalhar com um assunto extremamente atual: reconhecimento de objetos e rastreamento

# %% [markdown]
# Referências:

# %% [markdown]
# [https://www.pyimagesearch.com/2018/07/30/opencv-object-tracking/](https://www.pyimagesearch.com/2018/07/30/opencv-object-tracking/)
#
# [https://github.com/iArunava/YOLOv3-Object-Detection-with-OpenCV/](https://github.com/iArunava/YOLOv3-Object-Detection-with-OpenCV/)
#
# [https://www.pyimagesearch.com/2017/09/11/object-detection-with-deep-learning-and-opencv/](https://www.pyimagesearch.com/2017/09/11/object-detection-with-deep-learning-and-opencv/)

# %% [markdown]
# Ouça a explicacão do professor sobre rastreamento e deteção

# %% [markdown]
# ### 1. Executar os três exemplos
#
# Há três exemplos: `mobilenet_detection`, `yolov3_detection` e `tracking`.
#
# Os dois primeiros são reconhecedores de objetos, e o último é de rastreamento
#
#
# Um dos arquivos abaixo precisa ser baixado e salvo nas pasta  `yolov3_detection/yolov3-coco` .
#
# [https://www.dropbox.com/s/013ogt2bhwfzxwb/yolov3.weights?dl=0](https://www.dropbox.com/s/013ogt2bhwfzxwb/yolov3.weights?dl=0) ou [https://pjreddie.com/media/files/yolov3.weights](https://pjreddie.com/media/files/yolov3.weights)

# %% [markdown]
# ### mobilenet_detection
#
# **Comando: python3 object_detection_webcam.py --prototxt MobileNetSSD_deploy.prototxt.txt --model MobileNetSSD_deploy.caffemodel**
#
# Funcionamento comprovado no vídeo abaixo:
#
# <video width="360" height="203" controls src="Vídeos/mobilenet_detection.mov" />

# %% [markdown]
# ### yolo
#
# **Comando: python3 yolo.py**
#
# Funcionamento comprovado no vídeo abaixo:
#
# <video width="360" height="203" controls src="Vídeos/yolo.mov" />

# %% [markdown]
# ### tracking
#
# **Comando: python3 opencv_object_tracking.py**
#
# Funcionamento comprovado no vídeo abaixo:
#
# <video width="360" height="203" controls src="Vídeos/tracking.mov" />

# %% [markdown]
# ## 2. Identificar objeto

# %% [markdown]
# Escolha um dos projetos: `yolov3_detection` ou `mobilenet_detection` para basear seu código.
#
# Neste projeto, escolha uma categoria de objetos que o reconhecedor reconhece. Diga aqui qual foi sua escolha

# %% [markdown]
# Deve reconhecer a categoria: person
#
# No mesmo diretório de mobilenet_detection, arquivo: **Identificar_objeto.py**
#
# **Comando: python3 Identificar_objeto.py --prototxt MobileNetSSD_deploy.prototxt.txt --model MobileNetSSD_deploy.caffemodel**
#
# Funcionamento comprovado no vídeo abaixo:
#
# <video width="360" height="203" controls src="Vídeos/identificar_objeto.mov" />

# %% [markdown]
# ## 3. Rastrear

# %% [markdown]
# Implemente a seguinte funcionalidade: sempre que o objeto identificado em (2) estiver presente por mais que 5 frames seguidos, pare de rodar a identificação e comece a rastreá-lo.
#
# Faça um vídeo com a  demonstração funcionalidade e mostre o link ao professor
#
# No mesmo diretório de mobilenet_detection, arquivo: **identify_and_track.py**
#
# **Comando: python3 identify_and_track.py --prototxt MobileNetSSD_deploy.prototxt.txt --model MobileNetSSD_deploy.caffemodel**
#
# Funcionamento comprovado no vídeo abaixo:
#
# <video width="360" height="203" controls src="Vídeos/identify&track.mov" />

# %% [markdown]
# ## 4. Simulador

# %% [markdown]
#  Rode o simulador do Turtlebot (use o Waffle).  Veja o guia em [../guides/simulador_ros.md](../guides/simulador_ros.md)
#
#  Documente aqui as linhas necessárias para teleop e para abrir o Rviz
#
#  Faça um screenshot do seu simulação em execução

# %% [markdown]
# **Teleop:** roslaunch turtlebot3_teleop turtlebot3_teleop_key.launch
#
# **Rviz:** roslaunch turtlebot3_gazebo turtlebot3_gazebo_rviz.launch

# %% [markdown]
# file:///home/borg/Desktop/Screenshot%20from%202019-03-02%2016-38-38.png![image.png](attachment:image.png)

# %% [markdown]
# file:///home/borg/Desktop/Screenshot%20from%202019-03-02%2016-39-13.png![image.png](attachment:image.png)

# %% [markdown]
# file:///home/borg/Desktop/Screenshot%20from%202019-03-02%2016-44-51.png![image.png](attachment:image.png)

# %% [markdown]
# ## 5. Robô quadrado

# %% [markdown]
# Faça [este tutorial](../guides/projeto_rospython.md) de como criar um projeto Python que comanda o robô simulado.
#
# Usando o simulador, crie um código que faça o robô fazer uma trajetória que aproxima um quadrado.
#
# Baseie-se no código `roda.py`, construído durante o tutorial

# %% [markdown]
# #### Tartaruga

# %% [raw]
# #!/usr/bin/env python
#
# # rodar em terminais diferentes:
# # roscore
# # rosrun turtlesim turtlesim_node
# # rosrun meu_projeto quadrado.py
# import rospy
# from geometry_msgs.msg import Twist, Vector3
# from math import pi
#
# def move():
#     vel = Twist(Vector3(2,0,0), Vector3(0,0,0))
#
#     while not rospy.is_shutdown():
#
#         t0 = rospy.Time.now().to_sec()
#         current_distance = 0
#
#         while current_distance < 5:
#             pub.publish(vel)
#             t1 = rospy.Time.now().to_sec()
#             current_distance = vel.linear.x * (t1-t0)
#
#         vel.linear.x = 0
#         pub.publish(vel)
#         return
#
# def rotate():
#   vel = Twist(Vector3(0,0,0), Vector3(0,0,pi/2))
#
#   t0 = rospy.Time.now().to_sec()
#   current_angle = 0
#
#   while current_angle <= pi/2:
#       pub.publish(vel)
#       t1 = rospy.Time.now().to_sec()
#       current_angle = vel.angular.z * (t1-t0)
#
#   vel.angular.z = 0
#   pub.publish(vel)
#   return
#
# if __name__ == '__main__':
#     rospy.init_node('quadrado')
#     pub = rospy.Publisher('/turtle1/cmd_vel', Twist, queue_size=10)
#     try:
#         for i in range(4):
#             move()
#             rotate()
#     except rospy.ROSInterruptException: pass

# %% [markdown]
# file:///home/borg/Desktop/Screenshot%20from%202019-03-05%2016-52-24.png![image.png](attachment:image.png)

# %% [markdown]
# #### Adaptação para burger

# %% [raw]
# #!/usr/bin/env python
# # -*- coding:utf-8 -*-
# # export TURTLEBOT3_MODEL=burger
# # roslaunch turtlebot3_gazebo turtlebot3_world.launch
# # rosrun meu_projeto quadrado.py
# import rospy
# from geometry_msgs.msg import Twist, Vector3
# from math import pi
#
# def move():
#     v0 = Twist(Vector3(0,0,0), Vector3(0,0,0))
#     pub.publish(v0)
#     rospy.sleep(.2)
#     vel = Twist(Vector3(.25,0,0), Vector3(0,0,0))
#
#     while not rospy.is_shutdown():
#
#         t0 = rospy.Time.now().to_sec()
#         current_distance = 0
#
#         while current_distance < 1:
#             rospy.sleep(.1)
#             pub.publish(vel)
#             t1 = rospy.Time.now().to_sec()
#             current_distance = vel.linear.x * (t1-t0)
#
#         vel.linear.x = 0
#         pub.publish(vel)
#         rospy.sleep(3.0)
#         return
#
# def rotate():
#   v0 = Twist(Vector3(0,0,0), Vector3(0,0,0))
#   pub.publish(v0)
#   rospy.sleep(.2)
#   vel = Twist(Vector3(0,0,0), Vector3(0,0,pi/4))
#
#   t0 = rospy.Time.now().to_sec()
#   current_angle = 0
#
#   while current_angle <= pi/2:
#       rospy.sleep(.1)
#       pub.publish(vel)
#       t1 = rospy.Time.now().to_sec()
#       current_angle = vel.angular.z * (t1-t0)
#
#   vel.angular.z = 0
#   pub.publish(vel)
#   rospy.sleep(3.0)
#   return
#
# if __name__ == '__main__':
#     rospy.init_node('quadrado')
#     pub = rospy.Publisher('/cmd_vel', Twist, queue_size=3)
#     try:
# 	for i in range(4):
# 		move()
# 		rotate()
#     except rospy.ROSInterruptException: pass

# %% [markdown]
# ## 6. Robô indeciso

# %% [markdown]
# Usando o simulador e o LIDAR simulado, faça um robô avançar quando o obstáculo bem à sua frente estiver a menos de 1.0m e recuar quando estiver a mais de 1.02 m.
#
# Baseie-se no código `le_scan.py` e `roda.py`, desenvolvidos [durante o tutorial](../guides/projeto_rospython.md)

# %% [raw]
# #! /usr/bin/env python
# # -*- coding:utf-8 -*-
#
#
# import numpy as np
#
# import rospy
# from geometry_msgs.msg import Twist, Vector3
# from sensor_msgs.msg import LaserScan
#
# dist = 0
#
# def scaneou(dado):
# 	global dist
# 	print("Faixa valida: ", dado.range_min , " - ", dado.range_max )
# 	print("Leituras:")
# 	l = list(dado.ranges)
# 	#print(np.array(dado.ranges[0]).round(decimals=2))
# 	print(l[0])
# 	dist = l[0]
# 	#print("Intensities")
# 	#print(np.array(dado.intensities).round(decimals=2))
#
# if __name__=="__main__":
#
# 	rospy.init_node("le_scan")
#
# 	velocidade_saida = rospy.Publisher("/cmd_vel", Twist, queue_size = 3 )
# 	recebe_scan = rospy.Subscriber("/scan", LaserScan, scaneou)
#
# 	while not rospy.is_shutdown():
# 		if dist > 1.02:
# 			velocidade = Twist(Vector3(.1, 0, 0), Vector3(0, 0, 0))
# 			velocidade_saida.publish(velocidade)
# 		elif dist < 1.0:
# 			velocidade = Twist(Vector3(-.1, 0, 0), Vector3(0, 0, 0))
# 			velocidade_saida.publish(velocidade)
# 		else:
# 			velocidade = Twist(Vector3(0, 0, 0), Vector3(0, 0, 0))
# 			velocidade_saida.publish(velocidade)
